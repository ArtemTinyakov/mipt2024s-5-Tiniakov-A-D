# %%
from ultralytics import YOLO
import cv2

x128 = YOLO("runs/segment/train6/weights/best.pt")
x256 = YOLO("runs/segment/train7/weights/best.pt")
x384 = YOLO("runs/segment/train8/weights/best.pt")
x512 = YOLO("runs/segment/train9/weights/best.pt")
x640 = YOLO("runs/segment/train10/weights/best.pt")
x768 = YOLO("runs/segment/train11/weights/best.pt")

models = [x128, x256, x384, x512, x640, x768]
models_names = ["128x128", "256x256", "384x384", "512x512", "640x640", "768x768"]

# %%
import os
import numpy as np

data_path = "C:/Users/Artem/bboxed_barcodes_dataset/Validation/images/"
output_path = "C:/Users/Artem/mipt2024s-5-Tiniakov-A-D/yolo_input_size_tests/"

images = os.listdir(data_path)

# %%
import shutil

for i in range(len(models)):
    for image in images:
        models[i].predict(data_path+image, save=True, save_txt=True)
    shutil.move("C:/Users/Artem/runs/segment/predict", output_path+models_names[i])
# Out:
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_10050.jpg: 96x128 1 1d, 216.2ms
# Speed: 3.0ms preprocess, 216.2ms inference, 90.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 1 label saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_10090.jpg: 128x128 1 1d, 40.3ms
# Speed: 2.9ms preprocess, 40.3ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 2 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_1013 20.jpg: 128x128 1 2d, 13.9ms
# Speed: 1.1ms preprocess, 13.9ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 3 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_12580.jpg: 128x128 1 1d, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 4 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_12770.jpg: 128x128 1 1d, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 4.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 5 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_12780.jpg: 64x128 1 1d, 201.6ms
# Speed: 0.0ms preprocess, 201.6ms inference, 5.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 6 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240219_003634_0620.jpg: 128x128 1 2d, 14.9ms
# Speed: 1.1ms preprocess, 14.9ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 7 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240219_003634_0621.jpg: 64x128 1 1d, 1 2d, 15.4ms
# Speed: 0.9ms preprocess, 15.4ms inference, 3.9ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 8 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240220_194615_6370.jpg: 128x96 3 1ds, 332.4ms
# Speed: 1.0ms preprocess, 332.4ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 96)
# Results saved to runs\segment\predict
# 9 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240220_194615_6371.jpg: 128x64 1 1d, 213.7ms
# Speed: 0.0ms preprocess, 213.7ms inference, 7.0ms postprocess per image at shape (1, 3, 128, 64)
# Results saved to runs\segment\predict
# 10 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240220_194720_5890.jpg: 64x128 1 1d, 5.4ms
# Speed: 0.0ms preprocess, 5.4ms inference, 12.7ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 11 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240220_194738_1290.jpg: 64x128 1 1d, 18.8ms
# Speed: 1.0ms preprocess, 18.8ms inference, 3.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 12 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240220_195010_0070.jpg: 96x128 1 1d, 17.0ms
# Speed: 0.9ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 13 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_121013_8910.jpg: 128x128 1 2d, 16.0ms
# Speed: 1.1ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 14 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_121443_3100.jpg: 128x128 1 2d, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 15 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_121443_3101.jpg: 96x128 (no detections), 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 15 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215318_6170.jpg: 64x128 1 1d, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 3.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 16 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215318_6171.jpg: 128x96 1 1d, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 96)
# Results saved to runs\segment\predict
# 17 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215318_6172.jpg: 128x128 1 2d, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 13.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 18 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215406_0740.jpg: 64x128 1 1d, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 19 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215422_5190.jpg: 128x128 1 2d, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 20 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215422_5191.jpg: 128x128 1 1d, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 21 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215435_4660.jpg: 96x128 1 1d, 17.9ms
# Speed: 1.0ms preprocess, 17.9ms inference, 3.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 22 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215651_0030.jpg: 32x128 1 1d, 215.1ms
# Speed: 0.9ms preprocess, 215.1ms inference, 5.1ms postprocess per image at shape (1, 3, 32, 128)
# Results saved to runs\segment\predict
# 23 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215751_7600.jpg: 128x128 2 1ds, 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 4.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 24 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220013_8920.jpg: 96x128 1 1d, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 25 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220044_2600.jpg: 128x128 1 1d, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 26 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220044_2601.jpg: 128x128 1 1d, 1 2d, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 3.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 27 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220236_7950.jpg: 128x64 1 1d, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 128, 64)
# Results saved to runs\segment\predict
# 28 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220245_9640.jpg: 128x64 1 1d, 15.0ms
# Speed: 1.1ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 64)
# Results saved to runs\segment\predict
# 29 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220400_6720.jpg: 128x64 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 64)
# Results saved to runs\segment\predict
# 29 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220400_6721.jpg: 128x128 1 2d, 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 30 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_221714_2290.jpg: 96x128 1 1d, 17.8ms
# Speed: 1.0ms preprocess, 17.8ms inference, 3.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 31 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_222112_3310.jpg: 96x128 1 1d, 1 2d, 16.0ms
# Speed: 1.4ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 32 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_222112_3311.jpg: 96x128 2 1ds, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.4ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 33 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765200.jpg: 128x128 2 2ds, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 34 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765201.jpg: 128x128 1 2d, 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 35 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-7652010.jpg: 96x128 2 2ds, 9.7ms
# Speed: 1.0ms preprocess, 9.7ms inference, 3.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 36 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-7652011.jpg: 96x128 2 2ds, 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 4.9ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 37 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765202.jpg: 128x128 1 1d, 2 2ds, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 2.2ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 38 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765203.jpg: 128x128 2 2ds, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 39 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765204.jpg: 128x128 2 2ds, 25.5ms
# Speed: 0.0ms preprocess, 25.5ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 40 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765205.jpg: 128x128 1 2d, 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 41 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765206.jpg: 128x128 2 2ds, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 42 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765207.jpg: 128x128 1 2d, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 3.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 43 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765208.jpg: 128x128 2 2ds, 14.9ms
# Speed: 1.1ms preprocess, 14.9ms inference, 3.2ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 44 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765209.jpg: 64x128 2 2ds, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 45 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765240.jpg: 128x128 1 2d, 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 46 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765270.jpg: 96x128 1 1d, 17.6ms
# Speed: 0.0ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 47 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765271.jpg: 64x128 2 1ds, 14.1ms
# Speed: 0.9ms preprocess, 14.1ms inference, 2.5ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 48 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765272.jpg: 96x128 1 1d, 15.9ms
# Speed: 0.0ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 49 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765273.jpg: 32x128 1 1d, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 32, 128)
# Results saved to runs\segment\predict
# 50 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765280.jpg: 128x64 (no detections), 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 1.1ms postprocess per image at shape (1, 3, 128, 64)
# Results saved to runs\segment\predict
# 50 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765281.jpg: 96x128 1 2d, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 3.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 51 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765282.jpg: 64x128 1 1d, 15.4ms
# Speed: 0.0ms preprocess, 15.4ms inference, 3.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 52 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765283.jpg: 32x128 1 1d, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 32, 128)
# Results saved to runs\segment\predict
# 53 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765300.jpg: 64x128 1 1d, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 54 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765301.jpg: 32x128 (no detections), 9.3ms
# Speed: 0.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 32, 128)
# Results saved to runs\segment\predict
# 54 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765302.jpg: 96x128 1 1d, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 2.2ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 55 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765350.jpg: 64x128 2 1ds, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 56 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765351.jpg: 32x128 1 1d, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 32, 128)
# Results saved to runs\segment\predict
# 57 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765352.jpg: 32x128 1 1d, 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 3.0ms postprocess per image at shape (1, 3, 32, 128)
# Results saved to runs\segment\predict
# 58 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765353.jpg: 64x128 (no detections), 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 58 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765420.jpg: 128x96 1 1d, 20.9ms
# Speed: 1.0ms preprocess, 20.9ms inference, 4.0ms postprocess per image at shape (1, 3, 128, 96)
# Results saved to runs\segment\predict
# 59 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765421.jpg: 96x128 1 2d, 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 2.9ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 60 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765422.jpg: 128x96 1 1d, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 128, 96)
# Results saved to runs\segment\predict
# 61 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765423.jpg: 96x128 (no detections), 15.0ms
# Speed: 1.1ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 61 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765424.jpg: 128x128 (no detections), 15.9ms
# Speed: 1.1ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 61 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765425.jpg: 128x128 (no detections), 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 61 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765480.jpg: 128x128 1 2d, 17.2ms
# Speed: 0.0ms preprocess, 17.2ms inference, 3.6ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 62 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765481.jpg: 128x128 1 2d, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 63 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765482.jpg: 64x128 1 1d, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 64 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765483.jpg: 64x128 1 1d, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 65 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765520.jpg: 64x128 2 1ds, 19.0ms
# Speed: 0.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 66 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765521.jpg: 128x128 2 1ds, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 67 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765522.jpg: 32x128 1 1d, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.9ms postprocess per image at shape (1, 3, 32, 128)
# Results saved to runs\segment\predict
# 68 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765530.jpg: 128x128 1 1d, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 69 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765531.jpg: 32x128 (no detections), 16.3ms
# Speed: 0.0ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 128)
# Results saved to runs\segment\predict
# 69 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765532.jpg: 64x128 (no detections), 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 128)
# Results saved to runs\segment\predict
# 69 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-815520.jpg: 128x128 (no detections), 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 69 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-815530.jpg: 96x128 1 2d, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 70 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-815540.jpg: 96x128 1 2d, 15.9ms
# Speed: 0.0ms preprocess, 15.9ms inference, 3.0ms postprocess per image at shape (1, 3, 96, 128)
# Results saved to runs\segment\predict
# 71 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-815550.jpg: 128x128 1 1d, 1 2d, 16.1ms
# Speed: 0.9ms preprocess, 16.1ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs\segment\predict
# 72 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_10050.jpg: 192x256 2 1ds, 154.4ms
# Speed: 1.2ms preprocess, 154.4ms inference, 3.1ms postprocess per image at shape (1, 3, 192, 256)
# Results saved to runs\segment\predict
# 1 label saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_10090.jpg: 256x256 1 1d, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 4.1ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 2 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_1013 20.jpg: 256x224 1 2d, 267.1ms
# Speed: 1.0ms preprocess, 267.1ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 224)
# Results saved to runs\segment\predict
# 3 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_12580.jpg: 256x224 1 1d, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 224)
# Results saved to runs\segment\predict
# 4 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_12770.jpg: 224x256 1 1d, 165.3ms
# Speed: 1.1ms preprocess, 165.3ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 256)
# Results saved to runs\segment\predict
# 5 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_12780.jpg: 128x256 1 1d, 121.7ms
# Speed: 1.0ms preprocess, 121.7ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 256)
# Results saved to runs\segment\predict
# 6 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240219_003634_0620.jpg: 256x256 1 2d, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 7 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240219_003634_0621.jpg: 96x256 1 1d, 1 2d, 274.3ms
# Speed: 0.0ms preprocess, 274.3ms inference, 4.0ms postprocess per image at shape (1, 3, 96, 256)
# Results saved to runs\segment\predict
# 8 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240220_194615_6370.jpg: 256x192 1 1d, 172.9ms
# Speed: 1.0ms preprocess, 172.9ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 192)
# Results saved to runs\segment\predict
# 9 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240220_194615_6371.jpg: 256x128 1 1d, 159.9ms
# Speed: 1.0ms preprocess, 159.9ms inference, 4.0ms postprocess per image at shape (1, 3, 256, 128)
# Results saved to runs\segment\predict
# 10 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240220_194720_5890.jpg: 96x256 1 1d, 28.0ms
# Speed: 0.9ms preprocess, 28.0ms inference, 18.0ms postprocess per image at shape (1, 3, 96, 256)
# Results saved to runs\segment\predict
# 11 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240220_194738_1290.jpg: 96x256 1 1d, 26.5ms
# Speed: 1.0ms preprocess, 26.5ms inference, 3.1ms postprocess per image at shape (1, 3, 96, 256)
# Results saved to runs\segment\predict
# 12 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240220_195010_0070.jpg: 192x256 1 1d, 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 256)
# Results saved to runs\segment\predict
# 13 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_121013_8910.jpg: 256x256 1 2d, 34.1ms
# Speed: 1.1ms preprocess, 34.1ms inference, 4.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 14 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_121443_3100.jpg: 256x256 1 2d, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 1.9ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 15 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_121443_3101.jpg: 192x256 1 1d, 41.5ms
# Speed: 2.0ms preprocess, 41.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 256)
# Results saved to runs\segment\predict
# 16 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215318_6170.jpg: 128x256 1 1d, 45.5ms
# Speed: 2.0ms preprocess, 45.5ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 256)
# Results saved to runs\segment\predict
# 17 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215318_6171.jpg: 256x192 1 1d, 1 2d, 31.4ms
# Speed: 1.0ms preprocess, 31.4ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 192)
# Results saved to runs\segment\predict
# 18 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215318_6172.jpg: 256x256 1 1d, 1 2d, 33.9ms
# Speed: 2.1ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 19 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215406_0740.jpg: 96x256 1 1d, 27.8ms
# Speed: 2.0ms preprocess, 27.8ms inference, 3.0ms postprocess per image at shape (1, 3, 96, 256)
# Results saved to runs\segment\predict
# 20 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215422_5190.jpg: 224x256 1 2d, 42.1ms
# Speed: 1.9ms preprocess, 42.1ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 256)
# Results saved to runs\segment\predict
# 21 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215422_5191.jpg: 256x256 1 1d, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 22 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215435_4660.jpg: 160x256 1 1d, 167.3ms
# Speed: 1.0ms preprocess, 167.3ms inference, 2.9ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs\segment\predict
# 23 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215651_0030.jpg: 64x256 1 1d, 151.1ms
# Speed: 2.1ms preprocess, 151.1ms inference, 1.9ms postprocess per image at shape (1, 3, 64, 256)
# Results saved to runs\segment\predict
# 24 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_215751_7600.jpg: 224x256 1 1d, 29.7ms
# Speed: 2.0ms preprocess, 29.7ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 256)
# Results saved to runs\segment\predict
# 25 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220013_8920.jpg: 160x256 1 1d, 30.0ms
# Speed: 1.4ms preprocess, 30.0ms inference, 6.8ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs\segment\predict
# 26 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220044_2600.jpg: 224x256 1 1d, 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 256)
# Results saved to runs\segment\predict
# 27 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220044_2601.jpg: 256x224 1 1d, 1 2d, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 4.0ms postprocess per image at shape (1, 3, 256, 224)
# Results saved to runs\segment\predict
# 28 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220236_7950.jpg: 256x128 1 1d, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 4.0ms postprocess per image at shape (1, 3, 256, 128)
# Results saved to runs\segment\predict
# 29 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220245_9640.jpg: 256x96 1 1d, 188.0ms
# Speed: 2.0ms preprocess, 188.0ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 96)
# Results saved to runs\segment\predict
# 30 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220400_6720.jpg: 256x96 (no detections), 35.3ms
# Speed: 0.0ms preprocess, 35.3ms inference, 11.0ms postprocess per image at shape (1, 3, 256, 96)
# Results saved to runs\segment\predict
# 30 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220400_6721.jpg: 256x256 1 2d, 38.9ms
# Speed: 1.9ms preprocess, 38.9ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 31 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_221714_2290.jpg: 160x256 1 1d, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs\segment\predict
# 32 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_222112_3310.jpg: 192x256 1 1d, 1 2d, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 4.0ms postprocess per image at shape (1, 3, 192, 256)
# Results saved to runs\segment\predict
# 33 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_222112_3311.jpg: 192x256 1 1d, 34.5ms
# Speed: 0.9ms preprocess, 34.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 256)
# Results saved to runs\segment\predict
# 34 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765200.jpg: 256x256 2 2ds, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 35 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765201.jpg: 256x256 1 2d, 37.0ms
# Speed: 1.0ms preprocess, 37.0ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 36 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-7652010.jpg: 160x256 1 2d, 34.9ms
# Speed: 1.0ms preprocess, 34.9ms inference, 3.0ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs\segment\predict
# 37 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-7652011.jpg: 192x256 2 2ds, 34.6ms
# Speed: 2.0ms preprocess, 34.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results saved to runs\segment\predict
# 38 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765202.jpg: 224x256 2 2ds, 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 256)
# Results saved to runs\segment\predict
# 39 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765203.jpg: 224x256 2 2ds, 21.9ms
# Speed: 1.0ms preprocess, 21.9ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 256)
# Results saved to runs\segment\predict
# 40 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765204.jpg: 224x256 2 2ds, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 256)
# Results saved to runs\segment\predict
# 41 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765205.jpg: 256x256 1 2d, 20.3ms
# Speed: 1.0ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 42 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765206.jpg: 256x256 2 2ds, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.3ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 43 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765207.jpg: 256x256 1 2d, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 44 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765208.jpg: 224x256 2 2ds, 15.0ms
# Speed: 0.4ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 256)
# Results saved to runs\segment\predict
# 45 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765209.jpg: 160x256 3 2ds, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs\segment\predict
# 46 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765240.jpg: 256x256 1 2d, 16.8ms
# Speed: 1.0ms preprocess, 16.8ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 47 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765270.jpg: 160x256 1 1d, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs\segment\predict
# 48 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765271.jpg: 128x256 1 1d, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 128, 256)
# Results saved to runs\segment\predict
# 49 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765272.jpg: 160x256 1 1d, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs\segment\predict
# 50 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765273.jpg: 96x256 (no detections), 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.1ms postprocess per image at shape (1, 3, 96, 256)
# Results saved to runs\segment\predict
# 50 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765280.jpg: 256x128 1 2d, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 128)
# Results saved to runs\segment\predict
# 51 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765281.jpg: 160x256 1 2d, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs\segment\predict
# 52 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765282.jpg: 96x256 1 1d, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 2.9ms postprocess per image at shape (1, 3, 96, 256)
# Results saved to runs\segment\predict
# 53 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765283.jpg: 64x256 1 1d, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 64, 256)
# Results saved to runs\segment\predict
# 54 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765300.jpg: 128x256 1 1d, 20.4ms
# Speed: 0.0ms preprocess, 20.4ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 256)
# Results saved to runs\segment\predict
# 55 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765301.jpg: 32x256 1 1d, 294.9ms
# Speed: 0.0ms preprocess, 294.9ms inference, 4.3ms postprocess per image at shape (1, 3, 32, 256)
# Results saved to runs\segment\predict
# 56 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765302.jpg: 160x256 (no detections), 16.4ms
# Speed: 1.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs\segment\predict
# 56 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765350.jpg: 128x256 1 1d, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 128, 256)
# Results saved to runs\segment\predict
# 57 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765351.jpg: 32x256 1 1d, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 3.0ms postprocess per image at shape (1, 3, 32, 256)
# Results saved to runs\segment\predict
# 58 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765352.jpg: 64x256 1 1d, 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 64, 256)
# Results saved to runs\segment\predict
# 59 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765353.jpg: 128x256 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 256)
# Results saved to runs\segment\predict
# 59 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765420.jpg: 256x160 1 1d, 238.3ms
# Speed: 1.0ms preprocess, 238.3ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 160)
# Results saved to runs\segment\predict
# 60 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765421.jpg: 160x256 1 2d, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs\segment\predict
# 61 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765422.jpg: 256x160 1 1d, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 160)
# Results saved to runs\segment\predict
# 62 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765423.jpg: 192x256 1 1d, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 256)
# Results saved to runs\segment\predict
# 63 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765424.jpg: 256x256 1 1d, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 64 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765425.jpg: 256x256 1 2d, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 65 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765480.jpg: 224x256 1 2d, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 256)
# Results saved to runs\segment\predict
# 66 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765481.jpg: 256x224 1 2d, 16.9ms
# Speed: 1.0ms preprocess, 16.9ms inference, 3.1ms postprocess per image at shape (1, 3, 256, 224)
# Results saved to runs\segment\predict
# 67 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765482.jpg: 96x256 1 1d, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 96, 256)
# Results saved to runs\segment\predict
# 68 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765483.jpg: 96x256 1 1d, 18.0ms
# Speed: 0.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 96, 256)
# Results saved to runs\segment\predict
# 69 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765520.jpg: 128x256 2 1ds, 17.2ms
# Speed: 0.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 128, 256)
# Results saved to runs\segment\predict
# 70 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765521.jpg: 256x224 1 1d, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 224)
# Results saved to runs\segment\predict
# 71 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765522.jpg: 32x256 1 1d, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 32, 256)
# Results saved to runs\segment\predict
# 72 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765530.jpg: 256x256 1 1d, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs\segment\predict
# 73 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765531.jpg: 32x256 1 1d, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 32, 256)
# Results saved to runs\segment\predict
# 74 labels saved to runs\segment\predict\labels
#
# ...
# Results saved to runs\segment\predict
# 30 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220400_6720.jpg: 768x224 (no detections), 251.7ms
# Speed: 2.0ms preprocess, 251.7ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 224)
# Results saved to runs\segment\predict
# 30 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_220400_6721.jpg: 768x704 1 2d, 123.3ms
# Speed: 7.0ms preprocess, 123.3ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 704)
# Results saved to runs\segment\predict
# 31 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_221714_2290.jpg: 480x768 1 1d, 77.4ms
# Speed: 4.9ms preprocess, 77.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 768)
# Results saved to runs\segment\predict
# 32 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_222112_3310.jpg: 576x768 1 1d, 82.5ms
# Speed: 5.9ms preprocess, 82.5ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 768)
# Results saved to runs\segment\predict
# 33 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\IMG_20240222_222112_3311.jpg: 544x768 1 1d, 237.8ms
# Speed: 5.0ms preprocess, 237.8ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 768)
# Results saved to runs\segment\predict
# 34 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765200.jpg: 704x768 2 2ds, 99.5ms
# Speed: 5.1ms preprocess, 99.5ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 768)
# Results saved to runs\segment\predict
# 35 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765201.jpg: 768x704 2 2ds, 100.9ms
# Speed: 4.0ms preprocess, 100.9ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 704)
# Results saved to runs\segment\predict
# 36 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-7652010.jpg: 448x768 3 2ds, 16.9ms
# Speed: 3.1ms preprocess, 16.9ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 768)
# Results saved to runs\segment\predict
# 37 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-7652011.jpg: 512x768 2 2ds, 19.1ms
# Speed: 3.0ms preprocess, 19.1ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 768)
# Results saved to runs\segment\predict
# 38 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765202.jpg: 672x768 3 2ds, 38.0ms
# Speed: 3.9ms preprocess, 38.0ms inference, 10.0ms postprocess per image at shape (1, 3, 672, 768)
# Results saved to runs\segment\predict
# 39 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765203.jpg: 640x768 2 2ds, 23.9ms
# Speed: 3.1ms preprocess, 23.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 768)
# Results saved to runs\segment\predict
# 40 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765204.jpg: 608x768 2 2ds, 363.1ms
# Speed: 3.0ms preprocess, 363.1ms inference, 3.0ms postprocess per image at shape (1, 3, 608, 768)
# Results saved to runs\segment\predict
# 41 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765205.jpg: 768x768 3 2ds, 23.0ms
# Speed: 5.0ms preprocess, 23.0ms inference, 1.1ms postprocess per image at shape (1, 3, 768, 768)
# Results saved to runs\segment\predict
# 42 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765206.jpg: 768x768 3 2ds, 15.6ms
# Speed: 4.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 768)
# Results saved to runs\segment\predict
# 43 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765207.jpg: 768x704 1 2d, 23.7ms
# Speed: 4.0ms preprocess, 23.7ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 704)
# Results saved to runs\segment\predict
# 44 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765208.jpg: 608x768 2 2ds, 18.5ms
# Speed: 3.3ms preprocess, 18.5ms inference, 4.3ms postprocess per image at shape (1, 3, 608, 768)
# Results saved to runs\segment\predict
# 45 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765209.jpg: 416x768 3 2ds, 269.1ms
# Speed: 2.3ms preprocess, 269.1ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 768)
# Results saved to runs\segment\predict
# 46 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765240.jpg: 768x704 1 2d, 20.2ms
# Speed: 4.0ms preprocess, 20.2ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 704)
# Results saved to runs\segment\predict
# 47 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765270.jpg: 480x768 1 1d, 15.3ms
# Speed: 3.5ms preprocess, 15.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 768)
# Results saved to runs\segment\predict
# 48 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765271.jpg: 384x768 1 1d, 249.5ms
# Speed: 2.0ms preprocess, 249.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 768)
# Results saved to runs\segment\predict
# 49 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765272.jpg: 480x768 1 1d, 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 768)
# Results saved to runs\segment\predict
# 50 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765273.jpg: 224x768 (no detections), 291.8ms
# Speed: 1.0ms preprocess, 291.8ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 768)
# Results saved to runs\segment\predict
# 50 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765280.jpg: 768x384 (no detections), 268.1ms
# Speed: 3.0ms preprocess, 268.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 384)
# Results saved to runs\segment\predict
# 50 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765281.jpg: 448x768 1 2d, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 768)
# Results saved to runs\segment\predict
# 51 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765282.jpg: 256x768 1 1d, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 768)
# Results saved to runs\segment\predict
# 52 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765283.jpg: 160x768 1 1d, 250.5ms
# Speed: 1.0ms preprocess, 250.5ms inference, 3.0ms postprocess per image at shape (1, 3, 160, 768)
# Results saved to runs\segment\predict
# 53 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765300.jpg: 352x768 1 1d, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 768)
# Results saved to runs\segment\predict
# 54 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765301.jpg: 96x768 1 1d, 248.5ms
# Speed: 1.0ms preprocess, 248.5ms inference, 3.0ms postprocess per image at shape (1, 3, 96, 768)
# Results saved to runs\segment\predict
# 55 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765302.jpg: 416x768 (no detections), 26.7ms
# Speed: 2.0ms preprocess, 26.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 768)
# Results saved to runs\segment\predict
# 55 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765350.jpg: 384x768 1 1d, 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 768)
# Results saved to runs\segment\predict
# 56 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765351.jpg: 96x768 1 1d, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 96, 768)
# Results saved to runs\segment\predict
# 57 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765352.jpg: 192x768 1 1d, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 768)
# Results saved to runs\segment\predict
# 58 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765353.jpg: 384x768 1 1d, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 768)
# Results saved to runs\segment\predict
# 59 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765420.jpg: 768x448 1 1d, 261.1ms
# Speed: 2.0ms preprocess, 261.1ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 448)
# Results saved to runs\segment\predict
# 60 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765421.jpg: 480x768 (no detections), 28.0ms
# Speed: 2.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 768)
# Results saved to runs\segment\predict
# 60 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765422.jpg: 768x448 1 1d, 28.0ms
# Speed: 3.0ms preprocess, 28.0ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 448)
# Results saved to runs\segment\predict
# 61 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765423.jpg: 576x768 (no detections), 30.2ms
# Speed: 3.0ms preprocess, 30.2ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 768)
# Results saved to runs\segment\predict
# 61 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765424.jpg: 768x736 1 1d, 40.0ms
# Speed: 3.0ms preprocess, 40.0ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 736)
# Results saved to runs\segment\predict
# 62 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765425.jpg: 704x768 (no detections), 38.7ms
# Speed: 4.0ms preprocess, 38.7ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 768)
# Results saved to runs\segment\predict
# 62 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765480.jpg: 672x768 1 2d, 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 3.0ms postprocess per image at shape (1, 3, 672, 768)
# Results saved to runs\segment\predict
# 63 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765481.jpg: 768x640 1 2d, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 640)
# Results saved to runs\segment\predict
# 64 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765482.jpg: 224x768 1 1d, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 768)
# Results saved to runs\segment\predict
# 65 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765483.jpg: 288x768 1 1d, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 768)
# Results saved to runs\segment\predict
# 66 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765520.jpg: 384x768 1 1d, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 768)
# Results saved to runs\segment\predict
# 67 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765521.jpg: 768x640 1 1d, 26.0ms
# Speed: 3.0ms preprocess, 26.0ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 640)
# Results saved to runs\segment\predict
# 68 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765522.jpg: 96x768 1 1d, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 96, 768)
# Results saved to runs\segment\predict
# 69 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765530.jpg: 768x768 1 1d, 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 768)
# Results saved to runs\segment\predict
# 70 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765531.jpg: 96x768 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 768)
# Results saved to runs\segment\predict
# 70 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-765532.jpg: 256x768 1 1d, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 768)
# Results saved to runs\segment\predict
# 71 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-815520.jpg: 768x768 (no detections), 23.0ms
# Speed: 5.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 768)
# Results saved to runs\segment\predict
# 71 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-815530.jpg: 576x768 1 2d, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 768)
# Results saved to runs\segment\predict
# 72 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-815540.jpg: 608x768 1 2d, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 768)
# Results saved to runs\segment\predict
# 73 labels saved to runs\segment\predict\labels
#
# image 1/1 C:\Users\Artem\bboxed_barcodes_dataset\Validation\images\msg886302187-815550.jpg: 768x672 1 2d, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 672)
# Results saved to runs\segment\predict
# 74 labels saved to runs\segment\predict\labels

# %%
def calculate_iou(pred_mask, gt_mask):
    if len(pred_mask) == 0 or len(gt_mask) == 0:
        return 0
        
    intersection = np.logical_and(pred_mask, gt_mask).sum()
    union = np.logical_or(pred_mask, gt_mask).sum()
    iou = intersection / union if union > 0 else 0
    return iou

# %%
from copy import deepcopy

mean_ious = []

for i in range(len(models_names)):
    ground_truth_masks = []
    predicted_masks = []
    
    path_to_predicted_labels = "C:/Users/Artem/mipt2024s-5-Tiniakov-A-D/yolo_input_size_tests/" + models_names[i] + "/predict/labels/"
    path_to_gt_labels = "C:/Users/Artem/bboxed_barcodes_dataset/Validation/labels/"
    path_to_images = "C:/Users/Artem/bboxed_barcodes_dataset/Validation/images/"
    
    images_names = os.listdir(path_to_images)
    
    for name in images_names:
        name = name[:-4]
        img = cv2.imread(path_to_images+name+".jpg")
        height, width, _ = img.shape
        pred_mask = np.zeros((height, width, 1), dtype=np.uint8)
        gt_mask = np.zeros((height, width, 1), dtype=np.uint8)
        predicted_points = []
        gt_points = []

        predicted_labels = os.listdir(path_to_predicted_labels)

        if name+".txt" in predicted_labels:
            with open(path_to_predicted_labels+name+".txt", 'r') as fin:
                data = fin.readline().split(' ')[1:]
                for i in range(int(len(data)/2)):
                    predicted_points.append([int(float(data[i*2])*width), int(float(data[i*2+1])*height)])

        with open(path_to_gt_labels+name+".txt", 'r') as fin:
            data = fin.readline().split(' ')[1:]
            for i in range(int(len(data)/2)):
                gt_points.append([int(float(data[i*2])*width), int(float(data[i*2+1])*height)])
    
        predicted_points = np.array(predicted_points)
        gt_points = np.array(gt_points)

        if len(predicted_points) > 0:
            predicted_masks.append(cv2.fillPoly(pred_mask, pts=[predicted_points], color=(255)))
        else:
            predicted_masks.append(pred_mask)

        if len(gt_points) > 0:
            ground_truth_masks.append(cv2.fillPoly(gt_mask, pts=[gt_points], color=(255)))
        else:
            predicted_masks.append(gt_mask)

    ious = [calculate_iou(predicted_masks[i], ground_truth_masks[i]) for i in range(len(predicted_masks))]
    mean_ious.append(np.mean(ious))

# %%
mean_ious
# Out:
# [0.6411110765976297,
#  0.7950138789328041,
#  0.7235186691661133,
#  0.6853521360525955,
#  0.7593636285489671,
#  0.7021744387419286]
